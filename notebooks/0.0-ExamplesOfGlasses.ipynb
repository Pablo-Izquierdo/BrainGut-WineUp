# %% [markdown]
# ## Examples of the glasses used to train the model

# %%
import os
import json

import numpy as np
import matplotlib.pylab as plt

from imgclas import paths, utils, data_utils

# User parameters to set
TIMESTAMP = '2021-11-03_Lab_All_CopasVasos_All_reg'                       # timestamp of the model
MODEL_NAME = 'final_model.h5'                           # model to use to make the prediction
TOP_K = 2                                               # number of top classes predictions to save

# Set the timestamp
paths.timestamp = TIMESTAMP

# Load training configuration
conf_path = os.path.join(paths.get_conf_dir(), 'conf.json')
with open(conf_path) as f:
    conf = json.load(f)


# Set the timestamp
paths.timestamp = TIMESTAMP

figsize = 5
fig, axs = plt.subplots(3, 3, figsize=(figsize*3, figsize*3))
axs = axs.T.flatten() # lo hacemos despues

FILEPATH = '/srv/datos/Mosaico/Copa Balón vertical.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])


axs[0].imshow(image, alpha=0.68)
axs[0].set_title('Copa Balón', fontsize=30, pad=12)
axs[0].set_xticks([])
axs[0].set_yticks([])
axs[0].xaxis.set_visible(False)
axs[0].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Mosaico/Copa Cata vertical.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])


axs[1].imshow(image, alpha=0.68)
axs[1].set_title('Copa Cata', fontsize=30, pad=12)
axs[1].set_xticks([])
axs[1].set_yticks([])
axs[1].xaxis.set_visible(False)
axs[1].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Mosaico/Copa Borgoña vertical.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])


axs[3].imshow(image, alpha=0.68)
axs[3].set_title('Copa Borgoña', fontsize=30, pad=12)
axs[3].set_xticks([])
axs[3].set_yticks([])
axs[3].xaxis.set_visible(False)
axs[3].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Mosaico/Copa Burdeos vertical.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])


axs[6].imshow(image, alpha=0.58)
axs[6].set_title('Copa Burdeos', fontsize=30, pad=12)
axs[6].set_xticks([])
axs[6].set_yticks([])
axs[6].xaxis.set_visible(False)
axs[6].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Mosaico/Copa Chardonnay vertical.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])


axs[4].imshow(image, alpha=0.68)
axs[4].set_title('Copa Chardonnay', fontsize=30, pad=12)
axs[4].set_xticks([])
axs[4].set_yticks([])
axs[4].xaxis.set_visible(False)
axs[4].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Mosaico/Vaso Chato vertical.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])


axs[7].imshow(image, alpha=0.68)
axs[7].set_title('Vaso Chato', fontsize=30, pad=12)
axs[7].set_xticks([])
axs[7].set_yticks([])
axs[7].xaxis.set_visible(False)
axs[7].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Mosaico/Vaso Chiquito vertical.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])

axs[2].imshow(image, alpha=0.68)
axs[2].set_title('Vaso Chiquito', fontsize=30, pad=12)
axs[2].set_xticks([])
axs[2].set_yticks([])
axs[2].xaxis.set_visible(False)
axs[2].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Mosaico/Vaso Chato vertical.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])

axs[5].imshow(image, alpha=0.68)
axs[5].set_title('Vaso Chato', fontsize=30, pad=12)
axs[5].set_xticks([])
axs[5].set_yticks([])
axs[5].xaxis.set_visible(False)
axs[5].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Mosaico/Vaso Duralex vertical.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])

axs[5].imshow(image, alpha=0.38)
axs[5].set_title('Vaso Duralex', fontsize=30, pad=12)
axs[5].set_xticks([])
axs[5].set_yticks([])
axs[5].xaxis.set_visible(False)
axs[5].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Mosaico/Vaso Pinta vertical.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])

axs[8].imshow(image, alpha=0.68)
axs[8].set_title('Vaso Pinta', fontsize=30, pad=12)
axs[8].set_xticks([])
axs[8].set_yticks([])
axs[8].xaxis.set_visible(False)
axs[8].yaxis.set_visible(False)

fig.tight_layout(pad=1.5)
plt.savefig('/srv/image-results/mosaico.pdf',bbox_inches='tight')

# %%
import os
import json

import numpy as np
import matplotlib.pylab as plt

from imgclas import paths, utils, data_utils

# User parameters to set
TIMESTAMP = '2021-11-03_Lab_All_CopasVasos_All_reg'                       # timestamp of the model
MODEL_NAME = 'final_model.h5'                           # model to use to make the prediction
TOP_K = 2                                               # number of top classes predictions to save

# Set the timestamp
paths.timestamp = TIMESTAMP

# Load training configuration
conf_path = os.path.join(paths.get_conf_dir(), 'conf.json')
with open(conf_path) as f:
    conf = json.load(f)


# Set the timestamp
paths.timestamp = TIMESTAMP

figsize = 5
fig, axs = plt.subplots(3, 3, figsize=(figsize*3, figsize*3))
axs = axs.T.flatten() # lo hacemos despues

FILEPATH = '/srv/datos/Laboratorio/Madrid/copa Balon/Fondo blanco/Est_Mad_J_Balon_150_nd_nf_bl_sin_me_cen.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])


axs[0].imshow(image, alpha=0.7)
axs[0].set_title('Balloon wine glass', fontsize=26, pad=12)
axs[0].set_xticks([])
axs[0].set_yticks([])
axs[0].xaxis.set_visible(False)
axs[0].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Laboratorio/Madrid/copa Cata/Fondo blanco/Est_Mad_J_Cata_150_nd_nf_bl_sin_me_cen.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])


axs[1].imshow(image, alpha=0.6)
axs[1].set_title('Wine tasting glass', fontsize=26, pad=12)
axs[1].set_xticks([])
axs[1].set_yticks([])
axs[1].xaxis.set_visible(False)
axs[1].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Laboratorio/Madrid/copa Bor/Fondo blanco/Est_Mad_J_Bor_150_nd_nf_bl_sin_me_cen.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])


axs[3].imshow(image, alpha=0.7)
axs[3].set_title('Bourgogne wine glass', fontsize=26, pad=12)
axs[3].set_xticks([])
axs[3].set_yticks([])
axs[3].xaxis.set_visible(False)
axs[3].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Laboratorio/Madrid/copa Bur/Fondo blanco/Est_Mad_J_Bur_150_nd_nf_bl_sin_me_cen.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])


axs[6].imshow(image, alpha=0.6)
axs[6].set_title('Bordeaux wine glass', fontsize=26, pad=12)
axs[6].set_xticks([])
axs[6].set_yticks([])
axs[6].xaxis.set_visible(False)
axs[6].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Laboratorio/Madrid/copa Char/Fondo blanco/Est_Mad_J_Char_150_nd_nf_bl_sin_me_cen.jpg'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])


axs[4].imshow(image, alpha=0.7)
axs[4].set_title('Chardonnay wine glass', fontsize=26, pad=12)
axs[4].set_xticks([])
axs[4].set_yticks([])
axs[4].xaxis.set_visible(False)
axs[4].yaxis.set_visible(False)

# FILEPATH = '/srv/datos/Laboratorio/La Rioja/ICVV/Vaso Chato/Est_Rio_R_Chato_100_nd_nf_bl_sin_me_cen.JPG'
# FILEPATH = '/srv/datos/Laboratorio/La Rioja/ICVV/Vaso Chato/Est_Rio_R_Chato_100_nd_f_bl_sin_ce_cen.JPG'
FILEPATH = '/srv/datos/Laboratorio/La Rioja/CIBIR/vaso Chato/Est_Rio_C_Chato_100_nd_nf_bl_sin_me_cen.JPG'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])

img=image

axs[7].imshow(image[50:478, 50:478, :], alpha=0.7)
axs[7].set_title('Coffee glass', fontsize=26, pad=12)
axs[7].set_xticks([])
axs[7].set_yticks([])
axs[7].xaxis.set_visible(False)
axs[7].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Laboratorio/La Rioja/CIBIR/vaso Chiquito/Est_Rio_C_Chiqu_100_nd_nf_bl_sin_me_cen.JPG'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])

axs[2].imshow(image, alpha=0.7)
axs[2].set_title('Short rock glass', fontsize=26, pad=12)
axs[2].set_xticks([])
axs[2].set_yticks([])
axs[2].xaxis.set_visible(False)
axs[2].yaxis.set_visible(False)

FILEPATH = '/srv/datos/Laboratorio/La Rioja/CIBIR/vaso Duralex/Est_Rio_C_Dura_100_nd_nf_bl_sin_me_cen.JPG'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])

axs[5].imshow(image, alpha=0.7)
axs[5].set_title('Rock glass', fontsize=26, pad=12)
axs[5].set_xticks([])
axs[5].set_yticks([])
axs[5].xaxis.set_visible(False)
axs[5].yaxis.set_visible(False)

# FILEPATH = '/srv/datos/Laboratorio/La Rioja/CIBIR/vaso Pinta/Est_Rio_C_Pinta_100_nd_nf_bl_sin_me_cen.JPG'
# FILEPATH = '/srv/datos/Laboratorio/La Rioja/ICVV/Vaso Pinta/Est_Rio_R_Pinta_100_nd_nf_bl_sin_me_cen.jpg'
# FILEPATH = '/srv/datos/Laboratorio/Madrid/vaso Pinta/Fondo blanco/Est_Mad_J_Pinta_100_nd_nf_bl_sin_me_cen.jpg'
FILEPATH = '/srv/datos/Laboratorio/La Rioja/CIBIR/vaso Pinta/Est_Rio_C_Pinta_100_nd_nf_bl_sin_ce_cen.JPG'

image = data_utils.load_image(FILEPATH)#, filemode='local')
image = data_utils.resize_im(image, height=conf['model']['image_size'], width=conf['model']['image_size'])

axs[8].imshow(image, alpha=0.8)
axs[8].set_title('Water glass', fontsize=26, pad=12)
axs[8].set_xticks([])
axs[8].set_yticks([])
axs[8].xaxis.set_visible(False)
axs[8].yaxis.set_visible(False)

fig.tight_layout(pad=1.5)
plt.savefig('/srv/image-results/mosaico_full_2.pdf',bbox_inches='tight')

# %%
img.shape
# Out:
# (528, 528, 3)

# %%
plt.imshow(img[50:478, 50:478, :], alpha=0.8)
